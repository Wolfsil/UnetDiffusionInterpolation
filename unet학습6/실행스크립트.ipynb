# %% [markdown]
# 사전준비

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# k:\프로젝트\Py_Unet_Diffusion_Interpolation\unet학습6\실행스크립트.ipynb 셀 2 line 1
# ----> <a href='vscode-notebook-cell:/k%3A/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/Py_Unet_Diffusion_Interpolation/unet%ED%95%99%EC%8A%B56/%EC%8B%A4%ED%96%89%EC%8A%A4%ED%81%AC%EB%A6%BD%ED%8A%B8.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/k%3A/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8/Py_Unet_Diffusion_Interpolation/unet%ED%95%99%EC%8A%B56/%EC%8B%A4%ED%96%89%EC%8A%A4%ED%81%AC%EB%A6%BD%ED%8A%B8.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !python /content/drive/MyDrive/unet학습6/TrainingUnet.py
# Out:
# python: can't open file 'k:\content\drive\MyDrive\unet학습6\TrainingUnet.py': [Errno 2] No such file or directory
